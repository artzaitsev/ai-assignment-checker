# %%
from parser import zip_answers_to_df
import os

# %%
df = zip_answers_to_df(
    "data/candidates_answers.zip",
    tesseract_cmd=r"C:\Program Files\Tesseract-OCR\tesseract.exe"
)
#df.to_csv("answers_text.csv", index=False, encoding="utf-8-sig")
df.head()
# Out:
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 185 entries, 0 to 184
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   candidate_id  185 non-null    int64
#  1   file_name     185 non-null    object
#  2   ext           185 non-null    object
#  3   parser        185 non-null    object
#  4   text          185 non-null    object
#  5   error         2 non-null      object
# dtypes: int64(1), object(5)
# memory usage: 8.8+ KB

# %%
df[df['error'].notna()]
# Out:
#     candidate_id file_name   ext parser text  \
# 39            40   133.doc  .doc  error
#
#                                          error
# 39  Unsupported extension: .doc (file=133.doc)

# %%
df[df['ext'] == '.pdf']['text']
# Out:
# 11     1) Задание:\n● Имеем: Интернет магазин, таблиц...
# 18     1 задание) Я хочу предложить несколько изменен...
# 21     1. Измененная структура:\ncreate table clients...
# 25     1. В cient_id я бы использовал тип INT с автои...
# 27     1.\nПредставьте, что вы устроились работать да...
# 30     Подольский Иван Алексеевич\nЗадание 1.\nВ цело...
# 43     Задание 1.\nДанные в таблице cli(cid:7)nts изб...
# 45     1) Префикс "client_" для атрибутов избыточный ...
# 47     Задание 1.\nПредлагаю внести следующие коррект...
# 49     Задание 1.\nМожно внести следующие изменения:\...
# 50     Представьте, что вы устроились работать Дата-и...
# 54     1)\nclient_id – тип number может быть избыточе...
# 57     Гаденов Данила / Направление Data Engineer\nЗА...
# 60     1. Представьте, что вы устроились работать Дат...
# 65     client_id должен быть типа INTEGER PRIMARY KEY...
# 68     Задание 1.\n1. У client_id установил автоинкре...
# ...

# %%
df.iloc[178]['text']
# Out:
# 'Задание 1.\n\nЕсли работать с существующей архитектурой, то:\n\n1. Следует переопределить типы данных в числовых атрибутах:\nа. “client_id” на bigint;\nb. “city_id” Ha integer;\nс. “age” Ha smallint(ecnu субд He “postgresql” - tinyint );\n\n2. Оптимизировать атрибуты Client_name, client_surname уменьшив\nкол-во символов\n\n3. Если данные для авторизации клиента размещены в другой\nтаблице, то стоит убрать атрибут “login” из этой.\n\n4. Если такой таблицы нет, то необходимо добавить поле\n(“password” с типом varchar(64) )\n\nA так, я бы разделил персональные дынные пользователей и данные\nавторизации:\n1. Таблица для авторизации содержала бы UserID, login,\npassword(varchar(64)), role(“client” || “service-manager” || “admin”\n2. Таблица персональных данных с UserID, Fname(varchar(50)),\nSname(varchar(50)), email?(varchar(50)),\ncurrent_phone_number(varchar(20)).\n\n|...)\n\nЕсли у царя-батюшки имеются какие-то амбиции, планы на\nрасширение, то в качестве атрибута UserlD можно использ
# ...

# %%
df.shape
# Out:
# (185, 6)

# %%
folder_path = 'data'
file_path = os.path.join(folder_path, 'df.csv')

df.to_csv(file_path, index=False)

# %%
df[df['ext'] == '.docx']['text']
# Out:
# 0      Стоит поменять тип поля age на тип date и доба...
# 1      Ответ\nКомментарии по имеющимся столбцам\nclie...
# 2      Задание 1\nПредлагаемые мной изменения:\n1. cl...
# 3      Тестовое задание\nВера Судник\nЗадание 1\nМой ...
# 4      Изучая таблицу, оставленную прошлым Дата-инжен...
#                              ...
# 174    Поскольку нет конкретных данных и требований д...
# 180    1. Представьте, что вы устроились работать Дат...
# 182    В таблице представлены 7 столбцов:\nclient_id ...
# 183    ЗАДАНИЕ 1\nПредставьте, что вы устроились рабо...
# 184    1.\nДля полей “client_id” и “city_id” не требу...
# Name: text, Length: 87, dtype: object
